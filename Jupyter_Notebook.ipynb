# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# NAME : RAM
#
# CURRENT OCCUPATION : FULLSTACK DATA ANALYST INTERN
#
# DESIRED OCCUPATION : DATA SCIENTIST

# %% [markdown]
# I am interested in data science because i think data science is the future of data. Data science is the future of applied econometrics, I would definitely say, Data science, in my opinion, is the future of this kind of work. It is the only way to do it efficiently, replicably, and get great results. You have a lot more tools and a lot more flexibility in the way you can collect data, the way you can exploit multiple databases all at once, and produce something really usable as well. Data science is the future, and it is better to be on the cutting-edge than left behind.

# %% [markdown]
# THE BELOW CODE SHOULD RETURN ADDITION OF TWO STATEMENTS

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1.TOGGLE NUMBERED LINES
#
# 2.
#
# -> BULLETED LIST
#
# ![image-2.png](attachment:image-2.png)
